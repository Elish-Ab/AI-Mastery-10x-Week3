# %% [markdown]
# <a href="https://colab.research.google.com/github/Elish-Ab/AI-Mastery-10x-Week3/blob/task-1/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/MachineLearningRating_v3.txt', delimiter='|')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
df.describe()
# Out:
#        .000000000000  .000000000000.1
# count   42281.000000     42281.000000
# mean       69.083481        78.620624
# std       167.193891      2288.909982
# min         0.000000         0.000000
# 25%         0.000000         0.000000
# 50%         3.169035         0.000000
# 75%        43.859649         0.000000
# max      1313.794737    156214.473684

# %%
df.isnull().sum()
# Out:
# hensive - Taxi                        1
# Motor Comprehensive                   1
# Mobility Commercial Cover: Monthly    1
# Commercial                            1
# IFRS Constant                         1
# .000000000000                         1
# .000000000000.1                       1
# dtype: int64

# %%
# Univariate Analysis
numerical_cols = df.select_dtypes(include=[np.number]).columns
categorical_cols = df.select_dtypes(include=[object]).columns

# %%
# Distribution of Numerical Variables
for col in numerical_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    print(f'Distribution of {col}\n')
    plt.show()
# Out:
# Distribution of .000000000000
# Distribution of .000000000000.1

# %%
# Bar Charts for Categorical Variables
for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=df[col])
    plt.title(f'Bar Chart for {col}')
    print(f'Bar Chart for {col}\n')
    plt.show()
# Out:
# Bar Chart for hensive - Taxi
# Bar Chart for Motor Comprehensive
# Bar Chart for Mobility Commercial Cover: Monthly
# Bar Chart for Commercial
# Bar Chart for IFRS Constant

# %%
# Bivariate Analysis
plt.figure(figsize=(10, 8))
sns.heatmap(df[numerical_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Outlier Detection using Box Plots
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[numerical_cols])
plt.title('Box Plot for Numerical Variables')
plt.show()
